# %%
#Initialisation Stage

from selenium import webdriver
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time
import selenium.webdriver.chrome.service as service
import requests
driver_path ="C:\\Users\\OlatoyosiOlamideBaba\\OneDrive - Harnham Search and Selection Ltd\\Desktop\\Training\\Week 9\\chromedriver.exe"
driver = webdriver.Chrome(driver_path)
driver.get('https://www.goat.com/sneakers')
# Out:
# C:\Users\OlatoyosiOlamideBaba\AppData\Local\Temp\ipykernel_31020\2502905407.py:14: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(driver_path)

# %%
driver.find_element(By.ID, "onetrust-accept-btn-handler").click()

# %%
driver.execute_script('window.scrollTo(0,document.body.scrollHeight)')
time.sleep(3)
driver.execute_script('window.scrollTo(0,document.body.scrollHeight)')
time.sleep(3)
driver.execute_script('window.scrollTo(0,document.body.scrollHeight)')
time.sleep(3)
driver.execute_script('window.scrollTo(0,document.body.scrollHeight)')

# %%
shoe_name = []
for i in range(1,101):
    shoe = driver.find_element('xpath', '//*[@id="grid-body"]/div/div[1]/div[{}]/a/div[1]/div[1]/div[1]'.format(i)).text
    shoe_name.append(shoe)
shoe_name
# Out:
# ["Air Jordan 1 Retro High OG 'Stealth'",
#  "Dunk Low 'Black White'",
#  "Air Max Penny 1 'Orlando' 2022",
#  "Air Jordan 4 Retro PS 'Military Black'",
#  "Travis Scott x Air Jordan 1 Low OG TD 'Reverse Mocha'",
#  "Wmns Dunk Low 'Rose Whisper'",
#  "Air Jordan 4 Retro SE 'Black Canvas'",
#  "Dunk High 'White Black'",
#  "Dunk Low GS 'Triple Pink'",
#  "Air Jordan 3 Retro 'Fire Red' 2022",
#  "Yeezy Slides 'Flax'",
#  "Dunk Low GS 'Black White'",
#  "Wmns Dunk Low 'Black White'",
#  "Air Jordan 1 Low SE Craft 'Inside Out'",
#  "Dunk Low 'UCLA'",
#  "Yeezy Foam Runner 'Onyx'",
#  "Dunk Low 'Reverse Panda'",
#  "Yeezy Slides 'Onyx'",
#  "Dunk Low Premium 'Vast Grey'",
#  "Air Force 1 '07 'Triple White'",
#  "550 'Sea Salt'",
#  "Air Jordan 4 Retro 'Military Black'",
#  "550 'White Grey'",
#  "Off-White x Air Force 1 Mid 'Black'",
#  "Wmns Dunk Low SE 'Safari Mix'",
#  "Dunk High Retro 'Australia'",
#  "Dunk Low 'Championship Purple'",
#  "Air Jordan 12 Retro 'Stealth'",
# ...

# %%
link = []
for i in range(1,101):
    links = [x.get_attribute('href') for x in driver.find_elements('xpath', '//*[@id="grid-body"]/div/div[1]/div[{}]/a'.format(i))]
    link.extend(links)
link
# Out:
# ['https://www.goat.com/sneakers/air-jordan-1-retro-high-og-stealth-555088-037',
#  'https://www.goat.com/sneakers/dunk-low-black-white-dd1391-100',
#  'https://www.goat.com/sneakers/air-max-penny-1-orlando-2022-dn2487-001',
#  'https://www.goat.com/sneakers/air-jordan-4-retro-ps-military-black-bq7669-111',
#  'https://www.goat.com/sneakers/travis-scott-x-air-jordan-1-low-og-ps-reverse-mocha-do5441-162',
#  'https://www.goat.com/sneakers/wmns-dunk-low-rose-whisper-dd1503-118',
#  'https://www.goat.com/sneakers/air-jordan-4-retro-black-canvas-dh7138-006',
#  'https://www.goat.com/sneakers/dunk-high-white-black-dd1399-105',
#  'https://www.goat.com/sneakers/dunk-low-gs-triple-pink-dh9765-600',
#  'https://www.goat.com/sneakers/air-jordan-3-retro-fire-red-2022-dn3707-160',
#  'https://www.goat.com/sneakers/yeezy-slides-flax-yzy-sld-flax',
#  'https://www.goat.com/sneakers/dunk-low-gs-black-white-cw1590-100',
#  'https://www.goat.com/sneakers/wmns-dunk-low-black-white-dd1503-101',
# ...

# %%
link
# Out:
# ['https://www.goat.com/sneakers/air-jordan-1-retro-high-og-stealth-555088-037',
#  'https://www.goat.com/sneakers/dunk-low-black-white-dd1391-100',
#  'https://www.goat.com/sneakers/air-max-penny-1-orlando-2022-dn2487-001',
#  'https://www.goat.com/sneakers/air-jordan-4-retro-ps-military-black-bq7669-111',
#  'https://www.goat.com/sneakers/travis-scott-x-air-jordan-1-low-og-ps-reverse-mocha-do5441-162',
#  'https://www.goat.com/sneakers/wmns-dunk-low-rose-whisper-dd1503-118',
#  'https://www.goat.com/sneakers/air-jordan-4-retro-black-canvas-dh7138-006',
#  'https://www.goat.com/sneakers/dunk-high-white-black-dd1399-105',
#  'https://www.goat.com/sneakers/dunk-low-gs-triple-pink-dh9765-600',
#  'https://www.goat.com/sneakers/air-jordan-3-retro-fire-red-2022-dn3707-160',
#  'https://www.goat.com/sneakers/yeezy-slides-flax-yzy-sld-flax',
#  'https://www.goat.com/sneakers/dunk-low-gs-black-white-cw1590-100',
#  'https://www.goat.com/sneakers/wmns-dunk-low-black-white-dd1503-101',
# ...

# %%
sneakerlist =[]
def description(url):
    driver.get(url)
    
    try:
      fact = driver.find_element('xpath', '/html/body/div[1]/div/main/div/div[2]/div/div/div[2]/div[1]/p').text  
      sneakerlist.append(fact)

    except:
      fact='No Description found'
      sneakerlist.append(fact)

# %%
sneakerlist =[description(link[i]) for i in range(0,100)]
sneakerlist
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# c:\Users\OlatoyosiOlamideBaba\OneDrive - Harnham Search and Selection Ltd\Desktop\Training\Week 9\goatbot.ipynb Cell 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/OlatoyosiOlamideBaba/OneDrive%20-%20Harnham%20Search%20and%20Selection%20Ltd/Desktop/Training/Week%209/goatbot.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> sneakerlist =[description(link[i]) for i in range(0,100)]
#       <a href='vscode-notebook-cell:/c%3A/Users/OlatoyosiOlamideBaba/OneDrive%20-%20Harnham%20Search%20and%20Selection%20Ltd/Desktop/Training/Week%209/goatbot.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a> sneakerlist
#
# c:\Users\OlatoyosiOlamideBaba\OneDrive - Harnham Search and Selection Ltd\Desktop\Training\Week 9\goatbot.ipynb Cell 8 in <listcomp>(.0)
# ...

# %%
for i in range(0,100):
    description(link[i])

sneakerlist
# Out:
# ['The Air Jordan 1 Retro High OG ‘Stealth’ applies an understated two-tone finish to the sneaker that started it all. The all-leather build pairs a stark white base with neutral grey accents on the perforated toe box, signature Swoosh, and heel and collar overlay. The latter is branded with a retro Wings logo, while a woven Nike Air tag graces the breathable nylon tongue. The high-top rests on a rubber cupsole with an encapsulated Air-sole unit in the heel for lightweight cushioning.',
#  "The Nike Dunk Low ‘Black White’ also known as 'Panda' treats the retro model to an essential two-tone color scheme that accentuates the sneaker’s clean lines, developed by designer Peter Moore and responsible for the shoe’s easy transition from the hardwood to the street. The leather upper combines a white base with contrasting black overlays that wrap around the toe and heel. On both the woven tongue tag and heel tab, Nike branding in white stands out in relief against a black backdrop.",
# ...

# %%
#driver.get('https://www.goat.com/sneakers/air-jordan-1-retro-high-og-stealth-555088-037')
driver.get(str(link[0]))
fact = driver.find_element('xpath', '/html/body/div[1]/div/main/div/div[2]/div/div/div[2]/div[1]/p').text
fact
# Out:
# 'The Air Jordan 1 Retro High OG ‘Stealth’ applies an understated two-tone finish to the sneaker that started it all. The all-leather build pairs a stark white base with neutral grey accents on the perforated toe box, signature Swoosh, and heel and collar overlay. The latter is branded with a retro Wings logo, while a woven Nike Air tag graces the breathable nylon tongue. The high-top rests on a rubber cupsole with an encapsulated Air-sole unit in the heel for lightweight cushioning.'

# %%
link[0]
# Out:
# ['https://www.goat.com/sneakers/air-jordan-1-retro-high-og-stealth-555088-037']
